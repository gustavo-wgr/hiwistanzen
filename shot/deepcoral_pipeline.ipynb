# %% [markdown]
# # DeepCORAL Domain Adaptation Pipeline
#
# This notebook pre-trains a CNN on a source dataset (Phase 1) and then adapts it to an unlabeled target domain using CORAL loss (Phase 2). Both pretrained and adapted models are evaluated across multiple validation sets over several random seeds.

# %% [markdown]
# ## 1. Imports & Utilities
#
# Load libraries, define reproducibility, model, CORAL loss, and training/evaluation functions.

# %%
import os, sys, random
sys.path.insert(0, os.path.abspath('..'))
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from pkldataset import PKLDataset
from helpers import train_model, eval_model, set_seed

class CNN(nn.Module):
    def __init__(self, input_length=2800, num_classes=10, input_channels=1):
        super().__init__()
        self.conv1 = nn.Sequential(
            nn.Conv1d(input_channels,16,31,padding=15), nn.BatchNorm1d(16), nn.ReLU(True), nn.MaxPool1d(2)
        )
        self.conv2 = nn.Sequential(
            nn.Conv1d(16,32,31,padding=15), nn.BatchNorm1d(32), nn.ReLU(True), nn.MaxPool1d(2)
        )
        self.conv3 = nn.Sequential(
            nn.Conv1d(32,64,31,padding=15), nn.BatchNorm1d(64), nn.ReLU(True), nn.MaxPool1d(2)
        )
        conv_out = input_length//8
        self.feature_extractor = nn.Sequential(nn.Flatten(), nn.Linear(64*conv_out,128), nn.ReLU(True))
        self.classifier_head   = nn.Sequential(nn.Dropout(0.5), nn.Linear(128,num_classes))
    def forward(self,x):
        if x.dim()==2: x = x.unsqueeze(1)
        x = self.conv1(x); x = self.conv2(x); x = self.conv3(x)
        return self.classifier_head(self.feature_extractor(x))
    def extract_features(self,x):
        if x.dim()==2: x = x.unsqueeze(1)
        x = self.conv1(x); x = self.conv2(x); x = self.conv3(x)
        return self.feature_extractor(x)

def coral_loss(fs, ft):
    ns, nt = fs.size(0), ft.size(0)
    fs_c = fs - fs.mean(0,keepdim=True)
    ft_c = ft - ft.mean(0,keepdim=True)
    cov_s = fs_c.t()@fs_c/(ns-1)
    cov_t = ft_c.t()@ft_c/(nt-1)
    d = fs.size(1)
    return torch.sum((cov_s-cov_t)**2)/(4*d*d)

def train_deepcoral(model, source_loader, target_loader, criterion, optimizer, scheduler, num_epochs, lambda_coral, device, max_grad_norm=1.0):
    best_loss, best_state = float('inf'), None
    for epoch in range(1,num_epochs+1):
        model.train(); running=0
        it_s, it_t = iter(source_loader), iter(target_loader)
        steps = min(len(source_loader), len(target_loader))
        for _ in range(steps):
            xs, ys = next(it_s); xt,_=next(it_t)
            xs, ys, xt = xs.to(device), ys.to(device), xt.to(device)
            if ys.dim()>1: ys=ys.argmax(1)
            optimizer.zero_grad(); out_s=model(xs)
            loss_cls=criterion(out_s,ys)
            fs, ft = model.extract_features(xs), model.extract_features(xt)
            loss_c=coral_loss(fs,ft)
            loss=loss_cls+lambda_coral*loss_c
            print(f"  cls={loss_cls.item():.4f}  coral={loss_c.item():.4f}")
            loss.backward(); nn.utils.clip_grad_norm_(model.parameters(), max_grad_norm)
            optimizer.step(); running+=loss.item()*xs.size(0)
        scheduler.step(); epoch_loss=running/(steps*source_loader.batch_size)
        if epoch_loss<best_loss: best_loss, best_state=epoch_loss, model.state_dict().copy()
        print(f"[DeepCORAL] Epoch {epoch}/{num_epochs} — combined loss {epoch_loss:.4f}")
    model.load_state_dict(best_state); return model

# %% [markdown]
# ## 2. Configuration
#
# Define source & target paths, validation sets, seeds, device, losses, and initialize results storage.

# %%
train_path_1 = r"C:\Users\gus07\Desktop\data hiwi\preprocessing\HC\T197\RP"
train_path_dc = "../datasets/RPDC185/train_500"
val_paths = [
    "../datasets/RPDC185/val_1000",
    "../datasets/RPDC188/val_1000",
    "../datasets/RPDC191/val_1000",
    "../datasets/RPDC194/val_1000",
    "../datasets/RPDC197/val_1000",
]
seeds = [101,202,303,404,505,606,707,808,909,1001]
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
criterion = nn.CrossEntropyLoss()
lambda_coral = 1e-2
num_epochs_pre = 10
num_epochs_coral = 10
results_pre = {vp: [] for vp in val_paths}
results_adapt = {vp: [] for vp in val_paths}

# %% [markdown]
# ## 3. Pipeline: Pretrain & Adapt
#
# For each seed:
# 1. Split source and pretrain (Phase 1)
# 2. Evaluate pretrained model on validation sets
# 3. Adapt with DeepCORAL (Phase 2)
# 4. Evaluate adapted model on validation sets

# %%
for seed in seeds:
    print(f"\n>>> Pipeline with seed {seed}")
    set_seed(seed)
    train_ds, val_ds = PKLDataset.split_dataset(train_path_1)
    loader_tr = DataLoader(train_ds, batch_size=64, shuffle=True)
    loader_val = DataLoader(val_ds, batch_size=64, shuffle=False)
    model = CNN().to(device)
    opt = optim.Adam(model.parameters(), lr=1e-3, weight_decay=1e-5)
    sch = optim.lr_scheduler.StepLR(opt, step_size=50, gamma=0.1)
    model = train_model(model, loader_tr, criterion, opt, sch, num_epochs_pre, device)
    for vp in val_paths:
        acc = eval_model(model, DataLoader(PKLDataset(vp), batch_size=64, shuffle=False), device)
        results_pre[vp].append(acc)
        print(f"  [Pretrained] {vp}: {acc:.2f}%")
    pretrained_w = model.state_dict()
    model.load_state_dict(pretrained_w)
    opt = optim.Adam(model.parameters(), lr=1e-3, weight_decay=1e-5)
    sch = optim.lr_scheduler.StepLR(opt, step_size=50, gamma=0.1)
    loader_dc = DataLoader(PKLDataset(train_path_dc), batch_size=64, shuffle=True, drop_last=True)
    model = train_deepcoral(model, loader_tr, loader_dc, criterion, opt, sch, num_epochs_coral, lambda_coral, device)
    for vp in val_paths:
        acc = eval_model(model, DataLoader(PKLDataset(vp), batch_size=64, shuffle=False), device)
        results_adapt[vp].append(acc)
        print(f"  [Adapted  ] {vp}: {acc:.2f}%")
# Out:
# >>> Pipeline with seed 101
# Epoch 1/10, Loss: 0.7356
# Epoch 2/10, Loss: 0.1979
# Epoch 3/10, Loss: 0.1356
# Epoch 4/10, Loss: 0.1226
# Epoch 5/10, Loss: 0.1194
# Epoch 6/10, Loss: 0.0860
# Epoch 7/10, Loss: 0.0850
# Epoch 8/10, Loss: 0.0581
# Epoch 9/10, Loss: 0.0738
# Epoch 10/10, Loss: 0.0733
#   [Pretrained] ../datasets/RPDC185/val_1000: 33.55%
#   [Pretrained] ../datasets/RPDC188/val_1000: 43.58%
#   [Pretrained] ../datasets/RPDC191/val_1000: 53.64%
#   [Pretrained] ../datasets/RPDC194/val_1000: 52.80%
#   [Pretrained] ../datasets/RPDC197/val_1000: 50.20%
#   cls=0.3134  coral=2042.0173
#   cls=0.3550  coral=260.3205
#   cls=0.0548  coral=40.7759
#   cls=0.1895  coral=21.2862
#   cls=0.1805  coral=4.6125
#   cls=0.1817  coral=2.1691
#   cls=0.1969  coral=2.8057
# [DeepCORAL] Epoch 1/10 — combined loss 3.6017
#   cls=0.1694  coral=1.8193
#   cls=0.2173  coral=2.2610
#   cls=0.2239  coral=2.3835
#   cls=0.1070  coral=3.4300
#   cls=0.0988  coral=6.8810
#   cls=0.1390  coral=4.9837
#   cls=0.1184  coral=6.1575
# [DeepCORAL] Epoch 2/10 — combined loss 0.1933
#   cls=0.1554  coral=8.8615
#   cls=0.0788  coral=7.0485
#   cls=0.0555  coral=4.8710
#   cls=0.1177  coral=2.1041
#   cls=0.1007  coral=3.1814
#   cls=0.1222  coral=1.8536
#   cls=0.1517  coral=1.2057
# [DeepCORAL] Epoch 3/10 — combined loss 0.1533
#   cls=0.2185  coral=1.6166
#   cls=0.1504  coral=2.0315
#   cls=0.1201  coral=3.0657
#   cls=0.0858  coral=4.7339
#   cls=0.0659  coral=4.4387
#   cls=0.0268  coral=4.2673
#   cls=0.2124  coral=5.3526
# [DeepCORAL] Epoch 4/10 — combined loss 0.1621
#   cls=0.1060  coral=5.3584
#   cls=0.1037  coral=4.8330
#   cls=0.0563  coral=3.8883
#   cls=0.1910  coral=3.1570
#   cls=0.0331  coral=2.2273
#   cls=0.0592  coral=2.5628
#   cls=0.2616  coral=2.2283
# [DeepCORAL] Epoch 5/10 — combined loss 0.1505
#   cls=0.1481  coral=2.4268
#   cls=0.0692  coral=1.7868
#   cls=0.1149  coral=1.8213
#   cls=0.1075  coral=1.5831
#   cls=0.1038  coral=2.8000
#   cls=0.2142  coral=1.6466
#   cls=0.0371  coral=2.7220
# [DeepCORAL] Epoch 6/10 — combined loss 0.1347
#   cls=0.1380  coral=2.2688
#   cls=0.0495  coral=2.7016
#   cls=0.1053  coral=2.0264
#   cls=0.0479  coral=2.1384
#   cls=0.1187  coral=1.8315
#   cls=0.0450  coral=1.8721
#   cls=0.0590  coral=2.2306
# [DeepCORAL] Epoch 7/10 — combined loss 0.1020
#   cls=0.1849  coral=4.8242
#   cls=0.1079  coral=1.8738
#   cls=0.1474  coral=2.4274
#   cls=0.0218  coral=2.5155
#   cls=0.0616  coral=3.3786
#   cls=0.0950  coral=2.2535
#   cls=0.0767  coral=4.6889
# [DeepCORAL] Epoch 8/10 — combined loss 0.1307
#   cls=0.0929  coral=2.5703
#   cls=0.0623  coral=1.7168
#   cls=0.0390  coral=2.9612
#   cls=0.0772  coral=2.8483
#   cls=0.0926  coral=1.3153
#   cls=0.1223  coral=1.2333
#   cls=0.0944  coral=1.1539
# [DeepCORAL] Epoch 9/10 — combined loss 0.1027
#   cls=0.0821  coral=0.8845
#   cls=0.0713  coral=0.9867
#   cls=0.0607  coral=0.8490
#   cls=0.0744  coral=1.2036
#   cls=0.0701  coral=1.6669
#   cls=0.0996  coral=2.3288
#   cls=0.1666  coral=2.7139
# [DeepCORAL] Epoch 10/10 — combined loss 0.1044
#   [Adapted  ] ../datasets/RPDC185/val_1000: 49.13%
#   [Adapted  ] ../datasets/RPDC188/val_1000: 43.58%
#   [Adapted  ] ../datasets/RPDC191/val_1000: 60.14%
#   [Adapted  ] ../datasets/RPDC194/val_1000: 57.80%
#   [Adapted  ] ../datasets/RPDC197/val_1000: 49.30%
#
# >>> Pipeline with seed 202
# Epoch 1/10, Loss: 0.7505
# Epoch 2/10, Loss: 0.2476
# Epoch 3/10, Loss: 0.1626
# Epoch 4/10, Loss: 0.1119
# Epoch 5/10, Loss: 0.0926
# Epoch 6/10, Loss: 0.1057
# Epoch 7/10, Loss: 0.0770
# Epoch 8/10, Loss: 0.0985
# Epoch 9/10, Loss: 0.0783
# Epoch 10/10, Loss: 0.0655
#   [Pretrained] ../datasets/RPDC185/val_1000: 46.29%
#   [Pretrained] ../datasets/RPDC188/val_1000: 42.51%
#   [Pretrained] ../datasets/RPDC191/val_1000: 60.82%
#   [Pretrained] ../datasets/RPDC194/val_1000: 57.80%
#   [Pretrained] ../datasets/RPDC197/val_1000: 54.90%
#   cls=0.0378  coral=1459.9641
#   cls=0.0984  coral=527.9229
#   cls=0.1836  coral=142.7072
#   cls=0.4088  coral=50.0090
#   cls=0.4404  coral=21.8255
#   cls=0.3145  coral=6.1716
#   cls=0.5191  coral=2.8296
# [DeepCORAL] Epoch 1/10 — combined loss 3.4453
#   cls=0.3338  coral=1.6589
#   cls=0.3794  coral=1.6800
#   cls=0.2574  coral=3.2476
#   cls=0.2327  coral=5.4015
#   cls=0.2557  coral=9.0446
#   cls=0.2027  coral=11.0246
#   cls=0.2685  coral=17.2198
# [DeepCORAL] Epoch 2/10 — combined loss 0.3461
#   cls=0.3556  coral=8.6442
#   cls=0.1808  coral=10.7665
#   cls=0.2061  coral=8.0335
#   cls=0.1816  coral=6.7114
#   cls=0.2188  coral=5.1646
#   cls=0.1165  coral=7.7969
#   cls=0.0981  coral=3.9899
# [DeepCORAL] Epoch 3/10 — combined loss 0.2669
#   cls=0.0457  coral=7.5125
#   cls=0.2223  coral=4.5029
#   cls=0.1760  coral=3.5408
#   cls=0.1345  coral=2.9553
#   cls=0.1591  coral=2.0850
#   cls=0.1524  coral=2.0333
#   cls=0.1348  coral=1.5697
# [DeepCORAL] Epoch 4/10 — combined loss 0.1810
#   cls=0.1290  coral=3.0214
#   cls=0.2293  coral=3.4823
#   cls=0.1337  coral=2.5474
#   cls=0.2375  coral=3.1852
#   cls=0.0949  coral=3.8098
#   cls=0.0934  coral=5.1529
#   cls=0.0646  coral=5.2898
# [DeepCORAL] Epoch 5/10 — combined loss 0.1782
#   cls=0.1608  coral=7.8526
#   cls=0.0645  coral=3.3066
#   cls=0.0795  coral=4.6551
#   cls=0.0931  coral=6.7557
#   cls=0.0712  coral=3.8408
#   cls=0.1342  coral=3.6056
#   cls=0.0986  coral=3.5110
# [DeepCORAL] Epoch 6/10 — combined loss 0.1482
#   cls=0.1052  coral=3.7788
#   cls=0.0834  coral=3.5087
#   cls=0.0734  coral=4.6475
#   cls=0.1513  coral=1.6161
#   cls=0.0895  coral=2.4836
#   cls=0.1142  coral=2.5753
#   cls=0.1329  coral=2.7652
# [DeepCORAL] Epoch 7/10 — combined loss 0.1377
#   cls=0.0990  coral=2.1279
#   cls=0.1011  coral=3.5100
#   cls=0.0912  coral=2.0044
#   cls=0.1355  coral=2.4094
#   cls=0.3063  coral=3.5288
#   cls=0.0603  coral=4.7466
#   cls=0.1636  coral=3.0970
# [DeepCORAL] Epoch 8/10 — combined loss 0.1673
#   cls=0.0564  coral=2.9057
#   cls=0.0315  coral=3.9769
#   cls=0.0334  coral=3.7972
#   cls=0.0584  coral=2.7832
#   cls=0.0394  coral=3.9511
#   cls=0.1038  coral=2.1623
#   cls=0.0738  coral=1.7498
# [DeepCORAL] Epoch 9/10 — combined loss 0.0871
#   cls=0.0487  coral=1.8914
#   cls=0.0550  coral=1.5956
#   cls=0.1512  coral=2.1435
#   cls=0.2046  coral=2.0349
#   cls=0.1608  coral=1.9046
#   cls=0.1048  coral=0.9854
#   cls=0.0782  coral=1.8948
# [DeepCORAL] Epoch 10/10 — combined loss 0.1325
#   [Adapted  ] ../datasets/RPDC185/val_1000: 56.77%
#   [Adapted  ] ../datasets/RPDC188/val_1000: 59.76%
#   [Adapted  ] ../datasets/RPDC191/val_1000: 63.78%
#   [Adapted  ] ../datasets/RPDC194/val_1000: 60.90%
#   [Adapted  ] ../datasets/RPDC197/val_1000: 51.20%
#
# >>> Pipeline with seed 303
# Epoch 1/10, Loss: 0.8243
# Epoch 2/10, Loss: 0.2577
# Epoch 3/10, Loss: 0.1871
# Epoch 4/10, Loss: 0.1490
# Epoch 5/10, Loss: 0.1426
# Epoch 6/10, Loss: 0.1039
# Epoch 7/10, Loss: 0.1028
# Epoch 8/10, Loss: 0.0736
# Epoch 9/10, Loss: 0.0872
# Epoch 10/10, Loss: 0.0786
#   [Pretrained] ../datasets/RPDC185/val_1000: 36.03%
#   [Pretrained] ../datasets/RPDC188/val_1000: 55.61%
#   [Pretrained] ../datasets/RPDC191/val_1000: 49.54%
#   [Pretrained] ../datasets/RPDC194/val_1000: 44.00%
#   [Pretrained] ../datasets/RPDC197/val_1000: 43.80%
#   cls=0.0957  coral=1296.4580
#   cls=0.0752  coral=407.9437
#   cls=0.2880  coral=57.6331
#   cls=0.2389  coral=24.9127
#   cls=0.4084  coral=12.4023
#   cls=0.3137  coral=4.0179
#   cls=0.3555  coral=2.2073
# [DeepCORAL] Epoch 1/10 — combined loss 2.8330
#   cls=0.3490  coral=2.5125
#   cls=0.3468  coral=4.1121
#   cls=0.2068  coral=7.8091
#   cls=0.1153  coral=8.9664
#   cls=0.1413  coral=8.6939
#   cls=0.3410  coral=9.9156
#   cls=0.2169  coral=8.8209
# [DeepCORAL] Epoch 2/10 — combined loss 0.3179
#   cls=0.2233  coral=8.9799
#   cls=0.1693  coral=9.6737
#   cls=0.1897  coral=8.6684
#   cls=0.1461  coral=7.8611
#   cls=0.2089  coral=2.9183
#   cls=0.2162  coral=6.9558
#   cls=0.2085  coral=4.2362
# [DeepCORAL] Epoch 3/10 — combined loss 0.2650
#   cls=0.2831  coral=3.7593
#   cls=0.2188  coral=3.5575
#   cls=0.3713  coral=4.4560
#   cls=0.2066  coral=5.6915
#   cls=0.2480  coral=3.8578
#   cls=0.2463  coral=2.6254
#   cls=0.0893  coral=3.6282
# [DeepCORAL] Epoch 4/10 — combined loss 0.2770
#   cls=0.0820  coral=2.4370
#   cls=0.1760  coral=3.3906
#   cls=0.1005  coral=2.6218
#   cls=0.1433  coral=2.6513
#   cls=0.1133  coral=3.3775
#   cls=0.0812  coral=2.8790
#   cls=0.1502  coral=2.1895
# [DeepCORAL] Epoch 5/10 — combined loss 0.1488
#   cls=0.1672  coral=4.3842
#   cls=0.1539  coral=3.4703
#   cls=0.1209  coral=3.6191
#   cls=0.3354  coral=3.4489
#   cls=0.0767  coral=2.9664
#   cls=0.0918  coral=2.7775
#   cls=0.0736  coral=3.4494
# [DeepCORAL] Epoch 6/10 — combined loss 0.1801
#   cls=0.1577  coral=2.4719
#   cls=0.1942  coral=2.3999
#   cls=0.1150  coral=3.2806
#   cls=0.0642  coral=2.7332
#   cls=0.1481  coral=2.3866
#   cls=0.1067  coral=2.5012
#   cls=0.1659  coral=4.0953
# [DeepCORAL] Epoch 7/10 — combined loss 0.1643
#   cls=0.1273  coral=2.3627
#   cls=0.1403  coral=3.8808
#   cls=0.1129  coral=3.2045
#   cls=0.0515  coral=1.9831
#   cls=0.0494  coral=2.2512
#   cls=0.0426  coral=2.8956
#   cls=0.0332  coral=3.3212
# [DeepCORAL] Epoch 8/10 — combined loss 0.1080
#   cls=0.0293  coral=2.2583
#   cls=0.0482  coral=1.9952
#   cls=0.2033  coral=1.8715
#   cls=0.0693  coral=2.7074
#   cls=0.1267  coral=2.4708
#   cls=0.1243  coral=1.9270
#   cls=0.0663  coral=3.5206
# [DeepCORAL] Epoch 9/10 — combined loss 0.1193
#   cls=0.0707  coral=2.1121
#   cls=0.1800  coral=2.7967
#   cls=0.1703  coral=1.8560
#   cls=0.0446  coral=1.7499
#   cls=0.1408  coral=3.6316
#   cls=0.0428  coral=2.4684
#   cls=0.0824  coral=1.4755
# [DeepCORAL] Epoch 10/10 — combined loss 0.1275
#   [Adapted  ] ../datasets/RPDC185/val_1000: 49.27%
#   [Adapted  ] ../datasets/RPDC188/val_1000: 60.16%
#   [Adapted  ] ../datasets/RPDC191/val_1000: 54.78%
#   [Adapted  ] ../datasets/RPDC194/val_1000: 49.10%
#   [Adapted  ] ../datasets/RPDC197/val_1000: 48.60%
#
# >>> Pipeline with seed 404
# Epoch 1/10, Loss: 0.8452
# Epoch 2/10, Loss: 0.2060
# Epoch 3/10, Loss: 0.1378
# Epoch 4/10, Loss: 0.1005
# Epoch 5/10, Loss: 0.0886
# Epoch 6/10, Loss: 0.0733
# Epoch 7/10, Loss: 0.0731
# Epoch 8/10, Loss: 0.0651
# Epoch 9/10, Loss: 0.0799
# Epoch 10/10, Loss: 0.0508
#   [Pretrained] ../datasets/RPDC185/val_1000: 45.41%
#   [Pretrained] ../datasets/RPDC188/val_1000: 54.28%
#   [Pretrained] ../datasets/RPDC191/val_1000: 62.64%
#   [Pretrained] ../datasets/RPDC194/val_1000: 61.20%
#   [Pretrained] ../datasets/RPDC197/val_1000: 52.90%
#   cls=0.0469  coral=1571.4043
#   cls=0.0217  coral=177.6446
#   cls=0.0713  coral=38.4195
#   cls=0.2868  coral=5.4293
#   cls=0.4332  coral=1.5224
#   cls=0.2205  coral=3.1523
#   cls=0.1035  coral=5.8466
# [DeepCORAL] Epoch 1/10 — combined loss 2.7454
#   cls=0.1776  coral=6.4434
#   cls=0.0483  coral=6.1826
#   cls=0.0745  coral=7.7321
#   cls=0.0894  coral=5.2867
#   cls=0.1226  coral=3.0556
#   cls=0.1092  coral=2.2323
#   cls=0.1960  coral=2.7822
# [DeepCORAL] Epoch 2/10 — combined loss 0.1650
#   cls=0.1010  coral=4.3003
#   cls=0.1545  coral=4.6094
#   cls=0.0623  coral=8.0469
#   cls=0.1303  coral=5.7816
#   cls=0.0759  coral=4.4074
#   cls=0.0397  coral=3.2139
#   cls=0.0344  coral=1.6258
# [DeepCORAL] Epoch 3/10 — combined loss 0.1312
#   cls=0.0824  coral=2.6741
#   cls=0.1233  coral=1.6107
#   cls=0.0538  coral=3.3603
#   cls=0.0455  coral=2.4484
#   cls=0.0723  coral=1.9761
#   cls=0.0919  coral=1.5419
#   cls=0.0760  coral=1.8384
# [DeepCORAL] Epoch 4/10 — combined loss 0.0999
#   cls=0.1376  coral=2.5699
#   cls=0.0742  coral=2.2578
#   cls=0.0555  coral=3.6064
#   cls=0.0875  coral=4.1189
#   cls=0.0820  coral=2.1431
#   cls=0.0140  coral=2.7569
#   cls=0.0228  coral=1.8425
# [DeepCORAL] Epoch 5/10 — combined loss 0.0952
#   cls=0.0415  coral=2.5627
#   cls=0.2401  coral=1.5925
#   cls=0.0953  coral=1.0386
#   cls=0.1369  coral=1.9372
#   cls=0.1248  coral=1.0105
#   cls=0.1455  coral=1.1679
#   cls=0.0134  coral=1.6556
# [DeepCORAL] Epoch 6/10 — combined loss 0.1296
#   cls=0.0793  coral=1.8290
#   cls=0.0525  coral=2.0833
#   cls=0.1126  coral=2.2225
#   cls=0.0254  coral=3.8268
#   cls=0.0443  coral=3.9820
#   cls=0.1084  coral=5.1938
#   cls=0.1029  coral=2.7627
# [DeepCORAL] Epoch 7/10 — combined loss 0.1063
#   cls=0.0998  coral=2.1802
#   cls=0.0732  coral=1.4632
#   cls=0.0899  coral=1.0659
#   cls=0.1466  coral=1.1916
#   cls=0.0351  coral=1.1616
#   cls=0.1003  coral=1.5431
#   cls=0.0867  coral=1.6065
# [DeepCORAL] Epoch 8/10 — combined loss 0.1048
#   cls=0.0314  coral=2.3983
#   cls=0.0103  coral=2.6353
#   cls=0.0561  coral=1.3695
#   cls=0.0955  coral=2.2215
#   cls=0.0217  coral=1.8953
#   cls=0.1140  coral=3.5315
#   cls=0.1195  coral=2.2313
# [DeepCORAL] Epoch 9/10 — combined loss 0.0873
#   cls=0.0331  coral=2.6885
#   cls=0.0652  coral=2.2919
#   cls=0.0133  coral=2.2348
#   cls=0.0818  coral=2.7027
#   cls=0.0134  coral=2.3343
#   cls=0.1528  coral=1.7068
#   cls=0.0627  coral=1.4811
# [DeepCORAL] Epoch 10/10 — combined loss 0.0824
#   [Adapted  ] ../datasets/RPDC185/val_1000: 64.05%
#   [Adapted  ] ../datasets/RPDC188/val_1000: 62.03%
#   [Adapted  ] ../datasets/RPDC191/val_1000: 70.27%
#   [Adapted  ] ../datasets/RPDC194/val_1000: 71.30%
#   [Adapted  ] ../datasets/RPDC197/val_1000: 52.20%
#
# >>> Pipeline with seed 505
# Epoch 1/10, Loss: 0.7385
# Epoch 2/10, Loss: 0.1891
# Epoch 3/10, Loss: 0.1081
# Epoch 4/10, Loss: 0.0934
# Epoch 5/10, Loss: 0.0748
# Epoch 6/10, Loss: 0.0511
# Epoch 7/10, Loss: 0.0488
# Epoch 8/10, Loss: 0.0562
# Epoch 9/10, Loss: 0.0643
# Epoch 10/10, Loss: 0.0415
#   [Pretrained] ../datasets/RPDC185/val_1000: 40.68%
#   [Pretrained] ../datasets/RPDC188/val_1000: 47.86%
#   [Pretrained] ../datasets/RPDC191/val_1000: 60.14%
#   [Pretrained] ../datasets/RPDC194/val_1000: 53.60%
#   [Pretrained] ../datasets/RPDC197/val_1000: 50.70%
#   cls=0.0148  coral=3526.0884
#   cls=0.1314  coral=1401.4285
#   cls=0.0521  coral=215.0493
#   cls=0.1618  coral=25.3177
#   cls=0.1924  coral=7.9226
#   cls=0.1537  coral=6.9625
#   cls=0.2292  coral=2.8760
# [DeepCORAL] Epoch 1/10 — combined loss 7.5417
#   cls=0.0852  coral=4.1282
#   cls=0.1636  coral=2.2509
#   cls=0.1268  coral=4.3087
#   cls=0.1980  coral=5.7777
#   cls=0.0754  coral=5.3710
#   cls=0.1034  coral=3.9908
#   cls=0.0228  coral=5.8452
# [DeepCORAL] Epoch 2/10 — combined loss 0.1560
#   cls=0.0833  coral=2.5387
#   cls=0.1510  coral=4.0387
#   cls=0.1552  coral=4.4943
#   cls=0.0976  coral=3.9464
#   cls=0.1275  coral=2.2315
#   cls=0.1518  coral=1.7101
#   cls=0.1545  coral=1.9021
# [DeepCORAL] Epoch 3/10 — combined loss 0.1613
#   cls=0.1010  coral=2.6756
#   cls=0.0925  coral=2.8291
#   cls=0.1290  coral=2.9539
#   cls=0.0829  coral=3.1627
#   cls=0.0738  coral=2.8637
#   cls=0.0999  coral=2.3942
#   cls=0.1566  coral=5.4821
# [DeepCORAL] Epoch 4/10 — combined loss 0.1370
#   cls=0.0667  coral=3.8433
#   cls=0.1477  coral=3.4842
#   cls=0.0571  coral=4.8493
#   cls=0.2993  coral=3.2700
#   cls=0.2836  coral=3.0701
#   cls=0.1450  coral=3.1782
#   cls=0.1034  coral=1.8185
# [DeepCORAL] Epoch 5/10 — combined loss 0.1911
#   cls=0.1328  coral=2.6241
#   cls=0.1187  coral=2.6623
#   cls=0.0614  coral=3.3535
#   cls=0.1162  coral=5.0954
#   cls=0.1005  coral=2.1141
#   cls=0.0678  coral=4.1102
#   cls=0.0407  coral=2.4062
# [DeepCORAL] Epoch 6/10 — combined loss 0.1231
#   cls=0.0970  coral=2.1406
#   cls=0.1320  coral=2.0993
#   cls=0.0711  coral=2.1146
#   cls=0.0868  coral=2.6533
#   cls=0.0889  coral=2.3482
#   cls=0.0647  coral=1.9770
#   cls=0.0649  coral=4.5988
# [DeepCORAL] Epoch 7/10 — combined loss 0.1121
#   cls=0.0737  coral=2.6317
#   cls=0.0405  coral=2.3426
#   cls=0.0524  coral=3.3482
#   cls=0.0083  coral=3.4398
#   cls=0.0707  coral=2.5844
#   cls=0.0211  coral=3.5329
#   cls=0.0835  coral=1.6805
# [DeepCORAL] Epoch 8/10 — combined loss 0.0780
#   cls=0.0388  coral=1.0242
#   cls=0.0551  coral=1.2191
#   cls=0.0354  coral=1.0855
#   cls=0.0577  coral=1.7229
#   cls=0.0418  coral=1.9784
#   cls=0.0229  coral=2.8296
#   cls=0.0475  coral=1.9488
# [DeepCORAL] Epoch 9/10 — combined loss 0.0596
#   cls=0.0286  coral=3.3622
#   cls=0.0873  coral=2.8117
#   cls=0.0805  coral=2.5716
#   cls=0.0096  coral=3.9068
#   cls=0.0954  coral=1.9269
#   cls=0.0436  coral=1.7161
#   cls=0.0567  coral=1.1986
# [DeepCORAL] Epoch 10/10 — combined loss 0.0824
#   [Adapted  ] ../datasets/RPDC185/val_1000: 60.33%
#   [Adapted  ] ../datasets/RPDC188/val_1000: 51.34%
#   [Adapted  ] ../datasets/RPDC191/val_1000: 64.24%
#   [Adapted  ] ../datasets/RPDC194/val_1000: 63.40%
#   [Adapted  ] ../datasets/RPDC197/val_1000: 58.50%
#
# >>> Pipeline with seed 606
# Epoch 1/10, Loss: 0.6829
# Epoch 2/10, Loss: 0.1775
# Epoch 3/10, Loss: 0.1347
# Epoch 4/10, Loss: 0.1007
# Epoch 5/10, Loss: 0.0932
# Epoch 6/10, Loss: 0.0679
# Epoch 7/10, Loss: 0.0534
# Epoch 8/10, Loss: 0.0535
# Epoch 9/10, Loss: 0.0343
# Epoch 10/10, Loss: 0.0338
#   [Pretrained] ../datasets/RPDC185/val_1000: 36.03%
#   [Pretrained] ../datasets/RPDC188/val_1000: 50.80%
#   [Pretrained] ../datasets/RPDC191/val_1000: 52.73%
#   [Pretrained] ../datasets/RPDC194/val_1000: 50.90%
#   [Pretrained] ../datasets/RPDC197/val_1000: 50.50%
#   cls=0.0271  coral=786.6030
#   cls=0.0465  coral=253.3009
#   cls=0.1834  coral=85.7658
#   cls=0.2257  coral=16.7466
#   cls=0.2808  coral=4.9070
#   cls=0.3537  coral=2.9606
#   cls=0.2661  coral=1.4720
# [DeepCORAL] Epoch 1/10 — combined loss 1.8430
#   cls=0.2088  coral=3.7645
#   cls=0.1549  coral=6.7021
#   cls=0.1453  coral=7.1902
#   cls=0.0623  coral=7.6439
#   cls=0.0500  coral=5.7380
#   cls=0.1003  coral=4.5881
#   cls=0.1063  coral=6.2356
# [DeepCORAL] Epoch 2/10 — combined loss 0.1781
#   cls=0.0908  coral=5.7967
#   cls=0.2033  coral=7.2735
#   cls=0.1150  coral=5.5984
#   cls=0.2326  coral=7.2286
#   cls=0.1043  coral=9.3963
#   cls=0.0285  coral=3.6888
#   cls=0.0282  coral=3.5427
# [DeepCORAL] Epoch 3/10 — combined loss 0.1754
#   cls=0.0786  coral=4.8980
#   cls=0.0712  coral=4.1800
#   cls=0.0274  coral=3.3017
#   cls=0.1212  coral=2.9729
#   cls=0.0886  coral=1.8292
#   cls=0.0853  coral=2.3040
#   cls=0.0628  coral=2.0470
# [DeepCORAL] Epoch 4/10 — combined loss 0.1072
#   cls=0.0548  coral=6.6520
#   cls=0.1574  coral=2.4667
#   cls=0.0688  coral=2.6816
#   cls=0.0736  coral=2.1610
#   cls=0.0663  coral=2.2355
#   cls=0.0536  coral=2.8586
#   cls=0.0981  coral=3.3843
# [DeepCORAL] Epoch 5/10 — combined loss 0.1139
#   cls=0.0788  coral=3.9963
#   cls=0.0366  coral=3.7570
#   cls=0.0986  coral=2.3393
#   cls=0.0537  coral=3.0695
#   cls=0.0583  coral=3.9115
#   cls=0.0382  coral=3.1330
#   cls=0.0524  coral=2.7840
# [DeepCORAL] Epoch 6/10 — combined loss 0.0923
#   cls=0.0722  coral=2.8367
#   cls=0.0425  coral=3.9737
#   cls=0.0778  coral=1.9540
#   cls=0.0585  coral=1.8303
#   cls=0.0909  coral=1.2696
#   cls=0.0418  coral=1.5989
#   cls=0.1452  coral=1.5163
# [DeepCORAL] Epoch 7/10 — combined loss 0.0970
#   cls=0.0285  coral=1.6395
#   cls=0.0684  coral=1.7122
#   cls=0.0605  coral=2.0121
#   cls=0.0685  coral=2.8059
#   cls=0.1082  coral=2.2180
#   cls=0.2003  coral=2.0593
#   cls=0.0482  coral=2.1874
# [DeepCORAL] Epoch 8/10 — combined loss 0.1041
#   cls=0.0276  coral=2.2105
#   cls=0.0364  coral=1.7714
#   cls=0.1191  coral=1.3505
#   cls=0.0294  coral=1.6240
#   cls=0.0581  coral=1.4543
#   cls=0.0367  coral=2.5629
#   cls=0.0534  coral=1.4123
# [DeepCORAL] Epoch 9/10 — combined loss 0.0692
#   cls=0.0802  coral=1.8735
#   cls=0.0243  coral=1.5604
#   cls=0.0074  coral=1.3984
#   cls=0.0316  coral=2.4176
#   cls=0.1659  coral=1.5696
#   cls=0.0510  coral=2.2123
#   cls=0.0167  coral=1.7885
# [DeepCORAL] Epoch 10/10 — combined loss 0.0722
#   [Adapted  ] ../datasets/RPDC185/val_1000: 54.15%
#   [Adapted  ] ../datasets/RPDC188/val_1000: 62.03%
#   [Adapted  ] ../datasets/RPDC191/val_1000: 59.34%
#   [Adapted  ] ../datasets/RPDC194/val_1000: 60.30%
#   [Adapted  ] ../datasets/RPDC197/val_1000: 55.40%
#
# >>> Pipeline with seed 707
# Epoch 1/10, Loss: 0.7854
# Epoch 2/10, Loss: 0.2055
# Epoch 3/10, Loss: 0.1377
# Epoch 4/10, Loss: 0.1177
# Epoch 5/10, Loss: 0.1017
# Epoch 6/10, Loss: 0.0971
# Epoch 7/10, Loss: 0.0877
# Epoch 8/10, Loss: 0.0862
# Epoch 9/10, Loss: 0.0635
# Epoch 10/10, Loss: 0.0750
#   [Pretrained] ../datasets/RPDC185/val_1000: 51.53%
#   [Pretrained] ../datasets/RPDC188/val_1000: 62.30%
#   [Pretrained] ../datasets/RPDC191/val_1000: 59.11%
#   [Pretrained] ../datasets/RPDC194/val_1000: 55.00%
#   [Pretrained] ../datasets/RPDC197/val_1000: 50.20%
#   cls=0.0332  coral=488.3090
#   cls=0.0934  coral=168.1577
#   cls=0.4002  coral=38.6689
#   cls=0.4985  coral=21.6626
#   cls=0.4617  coral=8.1403
#   cls=0.2329  coral=11.4594
#   cls=0.1847  coral=6.3019
# [DeepCORAL] Epoch 1/10 — combined loss 1.3331
#   cls=0.2880  coral=3.0152
#   cls=0.1691  coral=4.1648
#   cls=0.1512  coral=6.9743
#   cls=0.1397  coral=5.9177
#   cls=0.1534  coral=6.1672
#   cls=0.2350  coral=5.5230
#   cls=0.1474  coral=10.6994
# [DeepCORAL] Epoch 2/10 — combined loss 0.2441
#   cls=0.0715  coral=4.5232
#   cls=0.2273  coral=6.1219
#   cls=0.1860  coral=5.5693
#   cls=0.1243  coral=4.3681
#   cls=0.0569  coral=5.3425
#   cls=0.0905  coral=5.5173
#   cls=0.1173  coral=3.6793
# [DeepCORAL] Epoch 3/10 — combined loss 0.1750
#   cls=0.0840  coral=2.6599
#   cls=0.1167  coral=2.3312
#   cls=0.0402  coral=2.5316
#   cls=0.0316  coral=3.2312
#   cls=0.1959  coral=2.3404
#   cls=0.0423  coral=2.5608
#   cls=0.0808  coral=4.5832
# [DeepCORAL] Epoch 4/10 — combined loss 0.1134
#   cls=0.1188  coral=4.7052
#   cls=0.0565  coral=4.2947
#   cls=0.1830  coral=4.1708
#   cls=0.0681  coral=3.3273
#   cls=0.2192  coral=2.5184
#   cls=0.0446  coral=5.4423
#   cls=0.1967  coral=2.0977
# [DeepCORAL] Epoch 5/10 — combined loss 0.1646
#   cls=0.1598  coral=1.4554
#   cls=0.1055  coral=2.0651
#   cls=0.1195  coral=1.7664
#   cls=0.0951  coral=1.5202
#   cls=0.0625  coral=2.4116
#   cls=0.0905  coral=2.7611
#   cls=0.0419  coral=1.6332
# [DeepCORAL] Epoch 6/10 — combined loss 0.1159
#   cls=0.0796  coral=2.3772
#   cls=0.0816  coral=1.8733
#   cls=0.1703  coral=2.6537
#   cls=0.0622  coral=4.2690
#   cls=0.0535  coral=2.2357
#   cls=0.0669  coral=2.2347
#   cls=0.0577  coral=1.9849
# [DeepCORAL] Epoch 7/10 — combined loss 0.1069
#   cls=0.0492  coral=1.6272
#   cls=0.0927  coral=3.6920
#   cls=0.0771  coral=2.2810
#   cls=0.0639  coral=1.9559
#   cls=0.1208  coral=2.3242
#   cls=0.0653  coral=2.5900
#   cls=0.0794  coral=1.8283
# [DeepCORAL] Epoch 8/10 — combined loss 0.1016
#   cls=0.0493  coral=2.5823
#   cls=0.0435  coral=1.8697
#   cls=0.0558  coral=1.9751
#   cls=0.1214  coral=2.7145
#   cls=0.0365  coral=1.8697
#   cls=0.0946  coral=2.1852
#   cls=0.1154  coral=1.7981
# [DeepCORAL] Epoch 9/10 — combined loss 0.0952
#   cls=0.0852  coral=1.7487
#   cls=0.0541  coral=1.5692
#   cls=0.0456  coral=1.8547
#   cls=0.0478  coral=1.3611
#   cls=0.0683  coral=2.1223
#   cls=0.0428  coral=1.9187
#   cls=0.0491  coral=1.2020
# [DeepCORAL] Epoch 10/10 — combined loss 0.0729
#   [Adapted  ] ../datasets/RPDC185/val_1000: 59.39%
#   [Adapted  ] ../datasets/RPDC188/val_1000: 66.58%
#   [Adapted  ] ../datasets/RPDC191/val_1000: 58.77%
#   [Adapted  ] ../datasets/RPDC194/val_1000: 60.30%
#   [Adapted  ] ../datasets/RPDC197/val_1000: 52.30%
#
# >>> Pipeline with seed 808
# Epoch 1/10, Loss: 0.7422
# Epoch 2/10, Loss: 0.1559
# Epoch 3/10, Loss: 0.1149
# Epoch 4/10, Loss: 0.0848
# Epoch 5/10, Loss: 0.0948
# Epoch 6/10, Loss: 0.0671
# Epoch 7/10, Loss: 0.0614
# Epoch 8/10, Loss: 0.0554
# Epoch 9/10, Loss: 0.0616
# Epoch 10/10, Loss: 0.0435
#   [Pretrained] ../datasets/RPDC185/val_1000: 45.49%
#   [Pretrained] ../datasets/RPDC188/val_1000: 55.88%
#   [Pretrained] ../datasets/RPDC191/val_1000: 62.19%
#   [Pretrained] ../datasets/RPDC194/val_1000: 61.50%
#   [Pretrained] ../datasets/RPDC197/val_1000: 49.00%
#   cls=0.1305  coral=1109.1343
#   cls=0.2831  coral=909.3068
#   cls=0.0532  coral=188.4208
#   cls=0.2083  coral=39.8158
#   cls=0.3069  coral=7.1890
#   cls=0.2659  coral=4.6569
#   cls=0.2605  coral=1.9152
# [DeepCORAL] Epoch 1/10 — combined loss 3.4447
#   cls=0.1422  coral=2.8763
#   cls=0.1816  coral=5.2190
#   cls=0.0354  coral=6.1531
#   cls=0.1312  coral=5.8641
#   cls=0.0723  coral=6.0599
#   cls=0.1173  coral=3.5181
#   cls=0.1185  coral=3.6423
# [DeepCORAL] Epoch 2/10 — combined loss 0.1617
#   cls=0.0744  coral=3.5045
#   cls=0.2886  coral=3.6423
#   cls=0.0971  coral=3.1970
#   cls=0.1263  coral=7.4163
#   cls=0.1524  coral=6.5176
#   cls=0.0175  coral=9.0716
#   cls=0.0520  coral=5.3820
# [DeepCORAL] Epoch 3/10 — combined loss 0.1708
#   cls=0.0865  coral=5.1337
#   cls=0.1381  coral=3.5329
#   cls=0.0688  coral=3.1370
#   cls=0.1222  coral=2.3416
#   cls=0.0868  coral=3.3644
#   cls=0.0560  coral=1.7777
#   cls=0.1019  coral=2.1277
# [DeepCORAL] Epoch 4/10 — combined loss 0.1249
#   cls=0.0429  coral=2.9140
#   cls=0.0519  coral=2.9760
#   cls=0.1727  coral=3.0266
#   cls=0.0925  coral=5.2640
#   cls=0.0159  coral=3.6771
#   cls=0.0321  coral=3.5283
#   cls=0.0631  coral=2.7730
# [DeepCORAL] Epoch 5/10 — combined loss 0.1018
#   cls=0.0581  coral=2.1831
#   cls=0.0866  coral=1.6950
#   cls=0.0497  coral=1.5398
#   cls=0.0913  coral=1.8672
#   cls=0.1141  coral=2.1905
#   cls=0.1165  coral=1.0533
#   cls=0.1288  coral=1.4297
# [DeepCORAL] Epoch 6/10 — combined loss 0.1092
#   cls=0.1087  coral=3.1127
#   cls=0.0907  coral=3.5473
#   cls=0.2294  coral=4.1149
#   cls=0.0187  coral=2.3557
#   cls=0.0680  coral=3.2282
#   cls=0.1510  coral=3.7067
#   cls=0.0787  coral=2.1114
# [DeepCORAL] Epoch 7/10 — combined loss 0.1382
#   cls=0.0427  coral=2.5094
#   cls=0.0654  coral=2.9411
#   cls=0.0398  coral=2.2118
#   cls=0.0358  coral=1.9436
#   cls=0.0307  coral=2.1388
#   cls=0.0339  coral=2.6077
#   cls=0.0678  coral=2.5223
# [DeepCORAL] Epoch 8/10 — combined loss 0.0693
#   cls=0.0659  coral=2.4493
#   cls=0.0407  coral=2.4481
#   cls=0.0258  coral=2.2655
#   cls=0.1812  coral=2.3349
#   cls=0.0929  coral=2.0089
#   cls=0.0782  coral=2.7911
#   cls=0.0217  coral=1.4866
# [DeepCORAL] Epoch 9/10 — combined loss 0.0949
#   cls=0.0292  coral=1.7769
#   cls=0.0342  coral=2.2829
#   cls=0.0445  coral=1.8455
#   cls=0.0733  coral=1.7492
#   cls=0.0718  coral=1.3673
#   cls=0.0179  coral=2.3346
#   cls=0.0590  coral=2.2823
# [DeepCORAL] Epoch 10/10 — combined loss 0.0666
#   [Adapted  ] ../datasets/RPDC185/val_1000: 54.66%
#   [Adapted  ] ../datasets/RPDC188/val_1000: 55.88%
#   [Adapted  ] ../datasets/RPDC191/val_1000: 62.41%
#   [Adapted  ] ../datasets/RPDC194/val_1000: 67.40%
#   [Adapted  ] ../datasets/RPDC197/val_1000: 48.20%
#
# >>> Pipeline with seed 909
# Epoch 1/10, Loss: 0.8431
# Epoch 2/10, Loss: 0.2649
# Epoch 3/10, Loss: 0.1521
# Epoch 4/10, Loss: 0.1372
# Epoch 5/10, Loss: 0.1072
# Epoch 6/10, Loss: 0.0978
# Epoch 7/10, Loss: 0.0830
# Epoch 8/10, Loss: 0.0658
# Epoch 9/10, Loss: 0.0596
# Epoch 10/10, Loss: 0.0450
#   [Pretrained] ../datasets/RPDC185/val_1000: 44.98%
#   [Pretrained] ../datasets/RPDC188/val_1000: 52.41%
#   [Pretrained] ../datasets/RPDC191/val_1000: 60.71%
#   [Pretrained] ../datasets/RPDC194/val_1000: 56.80%
#   [Pretrained] ../datasets/RPDC197/val_1000: 47.50%
#   cls=0.1670  coral=776.6277
#   cls=0.0729  coral=232.5845
#   cls=0.1275  coral=52.0233
#   cls=0.2392  coral=12.1356
#   cls=0.4506  coral=5.1186
#   cls=0.4048  coral=3.3124
#   cls=0.3431  coral=2.5709
# [DeepCORAL] Epoch 1/10 — combined loss 1.8070
#   cls=0.3016  coral=3.0993
#   cls=0.2002  coral=6.5486
#   cls=0.1238  coral=16.8588
#   cls=0.4126  coral=9.8932
#   cls=0.3062  coral=10.4630
#   cls=0.2380  coral=12.7772
#   cls=0.2249  coral=11.5337
# [DeepCORAL] Epoch 2/10 — combined loss 0.3599
#   cls=0.1664  coral=10.4451
#   cls=0.1203  coral=7.3619
#   cls=0.0422  coral=7.3045
#   cls=0.0668  coral=5.1587
#   cls=0.1336  coral=3.1206
#   cls=0.1204  coral=3.5992
#   cls=0.1467  coral=2.4676
# [DeepCORAL] Epoch 3/10 — combined loss 0.1701
#   cls=0.1223  coral=4.3894
#   cls=0.2135  coral=3.0492
#   cls=0.1470  coral=1.7989
#   cls=0.1146  coral=1.6796
#   cls=0.1035  coral=1.9963
#   cls=0.0639  coral=4.3565
#   cls=0.1381  coral=2.7159
# [DeepCORAL] Epoch 4/10 — combined loss 0.1575
#   cls=0.1009  coral=4.2018
#   cls=0.1115  coral=5.2576
#   cls=0.0541  coral=9.8669
#   cls=0.0845  coral=5.7669
#   cls=0.0581  coral=3.3840
#   cls=0.0510  coral=4.6239
#   cls=0.0646  coral=4.3991
# [DeepCORAL] Epoch 5/10 — combined loss 0.1285
#   cls=0.1069  coral=1.7036
#   cls=0.0593  coral=1.5223
#   cls=0.1357  coral=1.6736
#   cls=0.0460  coral=2.5845
#   cls=0.1707  coral=2.1498
#   cls=0.0503  coral=2.3527
#   cls=0.0539  coral=3.0096
# [DeepCORAL] Epoch 6/10 — combined loss 0.1104
#   cls=0.1104  coral=2.3784
#   cls=0.1492  coral=1.8785
#   cls=0.0437  coral=3.0458
#   cls=0.0462  coral=3.0948
#   cls=0.0632  coral=2.2280
#   cls=0.0789  coral=3.1060
#   cls=0.2254  coral=1.8809
# [DeepCORAL] Epoch 7/10 — combined loss 0.1276
#   cls=0.0620  coral=2.7359
#   cls=0.0398  coral=3.0839
#   cls=0.0670  coral=2.8940
#   cls=0.1209  coral=2.2262
#   cls=0.1096  coral=3.0032
#   cls=0.1481  coral=2.1602
#   cls=0.0363  coral=2.1528
# [DeepCORAL] Epoch 8/10 — combined loss 0.1095
#   cls=0.0695  coral=2.1849
#   cls=0.0802  coral=2.2831
#   cls=0.0473  coral=2.7028
#   cls=0.0896  coral=2.8758
#   cls=0.1169  coral=2.9805
#   cls=0.0474  coral=3.2772
#   cls=0.0872  coral=1.7492
# [DeepCORAL] Epoch 9/10 — combined loss 0.1027
#   cls=0.0481  coral=3.5096
#   cls=0.0207  coral=6.0076
#   cls=0.0807  coral=3.0263
#   cls=0.1693  coral=4.6967
#   cls=0.0667  coral=2.5321
#   cls=0.0517  coral=3.5239
#   cls=0.0771  coral=1.7950
# [DeepCORAL] Epoch 10/10 — combined loss 0.1093
#   [Adapted  ] ../datasets/RPDC185/val_1000: 57.28%
#   [Adapted  ] ../datasets/RPDC188/val_1000: 55.48%
#   [Adapted  ] ../datasets/RPDC191/val_1000: 63.21%
#   [Adapted  ] ../datasets/RPDC194/val_1000: 62.90%
#   [Adapted  ] ../datasets/RPDC197/val_1000: 52.10%
#
# >>> Pipeline with seed 1001
# Epoch 1/10, Loss: 0.7037
# Epoch 2/10, Loss: 0.1704
# Epoch 3/10, Loss: 0.1257
# Epoch 4/10, Loss: 0.1036
# Epoch 5/10, Loss: 0.0839
# Epoch 6/10, Loss: 0.0845
# Epoch 7/10, Loss: 0.0879
# Epoch 8/10, Loss: 0.0585
# Epoch 9/10, Loss: 0.0448
# Epoch 10/10, Loss: 0.0424
#   [Pretrained] ../datasets/RPDC185/val_1000: 43.45%
#   [Pretrained] ../datasets/RPDC188/val_1000: 54.01%
#   [Pretrained] ../datasets/RPDC191/val_1000: 58.66%
#   [Pretrained] ../datasets/RPDC194/val_1000: 48.80%
#   [Pretrained] ../datasets/RPDC197/val_1000: 54.00%
#   cls=0.0456  coral=953.0697
#   cls=0.0405  coral=178.3149
#   cls=0.2167  coral=51.3397
#   cls=0.2759  coral=14.6584
#   cls=0.3547  coral=6.6820
#   cls=0.4515  coral=2.8573
#   cls=0.3115  coral=2.5514
# [DeepCORAL] Epoch 1/10 — combined loss 1.9702
#   cls=0.2113  coral=4.7958
#   cls=0.3048  coral=5.9217
#   cls=0.1033  coral=8.2956
#   cls=0.0830  coral=6.3485
#   cls=0.1418  coral=6.4011
#   cls=0.0939  coral=3.8269
#   cls=0.1874  coral=5.6260
# [DeepCORAL] Epoch 2/10 — combined loss 0.2197
#   cls=0.1822  coral=6.0826
#   cls=0.3139  coral=4.5325
#   cls=0.1683  coral=5.5823
#   cls=0.2345  coral=4.8456
#   cls=0.0768  coral=5.4888
#   cls=0.1114  coral=5.6530
#   cls=0.2225  coral=3.2944
# [DeepCORAL] Epoch 3/10 — combined loss 0.2378
#   cls=0.1147  coral=5.2085
#   cls=0.1594  coral=4.2206
#   cls=0.0744  coral=4.0424
#   cls=0.1228  coral=3.4195
#   cls=0.1187  coral=4.5778
#   cls=0.0841  coral=3.1266
#   cls=0.0915  coral=3.4900
# [DeepCORAL] Epoch 4/10 — combined loss 0.1495
#   cls=0.1030  coral=4.1710
#   cls=0.0625  coral=2.9457
#   cls=0.0785  coral=3.1654
#   cls=0.1573  coral=2.8615
#   cls=0.1748  coral=2.4878
#   cls=0.0431  coral=3.2780
#   cls=0.1009  coral=3.7378
# [DeepCORAL] Epoch 5/10 — combined loss 0.1352
#   cls=0.0882  coral=2.5200
#   cls=0.1405  coral=5.7704
#   cls=0.0727  coral=2.6267
#   cls=0.0573  coral=2.9848
#   cls=0.0381  coral=3.9255
#   cls=0.0452  coral=2.6937
#   cls=0.0507  coral=2.1724
# [DeepCORAL] Epoch 6/10 — combined loss 0.1028
#   cls=0.0274  coral=2.6983
#   cls=0.0450  coral=3.2286
#   cls=0.0522  coral=2.8220
#   cls=0.0684  coral=1.8807
#   cls=0.1038  coral=2.1827
#   cls=0.0682  coral=2.3634
#   cls=0.1002  coral=2.1262
# [DeepCORAL] Epoch 7/10 — combined loss 0.0912
#   cls=0.0560  coral=2.2904
#   cls=0.0885  coral=2.6384
#   cls=0.0685  coral=2.2662
#   cls=0.1043  coral=3.0804
#   cls=0.1364  coral=2.4175
#   cls=0.0656  coral=1.7950
#   cls=0.0605  coral=3.0321
# [DeepCORAL] Epoch 8/10 — combined loss 0.1079
#   cls=0.0252  coral=2.2821
#   cls=0.1053  coral=2.4915
#   cls=0.1095  coral=2.7086
#   cls=0.1151  coral=3.2821
#   cls=0.0604  coral=2.6318
#   cls=0.1203  coral=2.0235
#   cls=0.0326  coral=1.4823
# [DeepCORAL] Epoch 9/10 — combined loss 0.1054
#   cls=0.0297  coral=1.9672
#   cls=0.1710  coral=1.6295
#   cls=0.1092  coral=1.8020
#   cls=0.0453  coral=1.7416
#   cls=0.0568  coral=2.7802
#   cls=0.0671  coral=1.6357
#   cls=0.0706  coral=1.9569
# [DeepCORAL] Epoch 10/10 — combined loss 0.0978
#   [Adapted  ] ../datasets/RPDC185/val_1000: 60.99%
#   [Adapted  ] ../datasets/RPDC188/val_1000: 58.96%
#   [Adapted  ] ../datasets/RPDC191/val_1000: 65.38%
#   [Adapted  ] ../datasets/RPDC194/val_1000: 63.50%
#   [Adapted  ] ../datasets/RPDC197/val_1000: 53.50%

# %% [markdown]
# ## 4. Summary of Results
#
# Compute mean and standard deviation over seeds for both pretrained and adapted models.

# %%
print("\n=== Pretrained (HC only) ===")
for vp, vals in results_pre.items():
    arr = np.array(vals)
    print(f"{vp}: mean = {arr.mean():.2f}%, std = {arr.std(ddof=1):.2f}%")
print("\n=== After DeepCORAL Adaptation ===")
for vp, vals in results_adapt.items():
    arr = np.array(vals)
    print(f"{vp}: mean = {arr.mean():.2f}%, std = {arr.std(ddof=1):.2f}%")
# Out:
# === Pretrained (HC only) ===
# ../datasets/RPDC185/val_1000: mean = 42.34%, std = 5.65%
# ../datasets/RPDC188/val_1000: mean = 51.93%, std = 5.99%
# ../datasets/RPDC191/val_1000: mean = 58.02%, std = 4.46%
# ../datasets/RPDC194/val_1000: mean = 54.24%, std = 5.47%
# ../datasets/RPDC197/val_1000: mean = 50.37%, std = 3.22%
#
# === After DeepCORAL Adaptation ===
# ../datasets/RPDC185/val_1000: mean = 56.60%, std = 4.90%
# ../datasets/RPDC188/val_1000: mean = 57.58%, std = 6.46%
# ../datasets/RPDC191/val_1000: mean = 62.23%, std = 4.25%
# ../datasets/RPDC194/val_1000: mean = 61.69%, std = 5.88%
# ../datasets/RPDC197/val_1000: mean = 52.13%, std = 3.16%
